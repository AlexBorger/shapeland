# %% [markdown]
# # Notebook Intentions
#
# The purpose of this notebook is to simulate an amusement park.

# %%
from park import Park
from behavior_reference import BEHAVIOR_ARCHETYPE_PARAMETERS

# %% [markdown]
# ### Book Keeping
#
#     - Version: dictates the location performance graphs are stored
#     - Verbosity: controls much information is displayed during a simulation, increase to show more info
#     - Show Plots: controls whether park plots are displayed in this notebook
#     - RNG Seed: seeds random number generators to enforce identical results across runs/machines

# %%
VERSION = "20K All FP - MIKE"
VERBOSITY = 1
SHOW_PLOTS = True
RNG_SEED = 10

# %% [markdown]
# ## Park
#
# The park contains Agents, Attractions and Activities.
#
# - Total Daily Agents: dictates how many agents visit the park within a day
# - Hourly Percent: dictates what percentage of Total Daily Agents visits the park at each hour
# - Perfect Arrivals: enforces that the exact amount of Total Daily Agents arrives during the day
# - Expedited Pass Ability Percent: percent of agents aware of expeditied passes
# - Expedited Threshold: acceptable queue wait time length before searching for an expedited pass
# - Expedited Limit: total number of expedited pass an agent can hold at any given time

# %%
TOTAL_DAILY_AGENTS = 50000 #38047 actual average
PERFECT_ARRIVALS = True
HOURLY_PERCENT = {
    "10:00 AM": 18,
    "11:00 AM": 23,
    "12:00 PM": 17,
    "1:00 PM": 15,
    "2:00 PM": 9,
    "3:00 PM": 7,
    "4:00 PM": 2,
    "5:00 PM": 5,
    "6:00 PM": 3,
    "7:00 PM": 1,
    "8:00 PM": 0,
    "9:00 PM": 0,
    "10:00 PM": 0
}
EXP_ABILITY_PCT = 0.95
EXP_THRESHOLD = 30
EXP_LIMIT = 1

# %% [markdown]
# ## Agents
#
# The park is populated by agents. Agents visit attractions and activities. They make decisions about where to go based on their preferences, the popularity of attractions and activities and waiting times. Each Agent has a behavioral archetype.
#
# - Ride Enthusiast: wants to stay for a long time, go on as many attractions as possible, doesn't want to visit activites, doesn't mind waiting
# - Ride Favorer: wants to go on a lot of attractions, but will vists activites occasionally, will wait for a while in a queue
# - Park Tourer: wants to stay for a long time and wants to see attractions and activities equally, reasonable about wait times
# - Park Visitor: doesn't want to stay long and wants to see attractions and activities equally, inpatient about wait times
# - Activity Favorer: doesn't want to stay long and prefers activities, reasonable about wait times
# - Activity Enthusiast: wants to visit a lot of activities, reasonable about wait times
#
# Archetypes can be tweaked and new archetypes can be added in `behavior_reference.py`.
#
# - Agent Archetype Distribution: dictates the probability an agent will have a particular behavioral archetype

# %%
AGENT_ARCHETYPE_DISTRIBUTION = {
    "ride_enthusiast": 10,
    "ride_favorer": 15,
    "park_tourer": 25,
    "park_visitor": 30,
    "activity_favorer": 15,
    "activity_enthusiast": 5,
}

# %% [markdown]
# ## Attractions
#
# Attractions are essentially rides within a park.
#
# - Attractions: list of dictionaries that describe the attractions within the park
#     - Name: name of the attraction
#     - Run Time: How long the attraction take to run, in minutes
#     - Capacity: Maximium number of agents that can be on the attraction during a run
#     - Popularity: Value from 1-10 that describes how popular an attraction is with respect to other attractions
#     - Expedited Queue: Dictates whether the attraction has an expedited queue or not
#     - Expedited Queue Ratio: Dictates what percentage of attraction capacity is devoted to members of the expedited queue
#     - Child Eligible: Dictates whether children can ride the attraction
#     - Adult Eligible: Dictates whether adults can ride the attraction

# %%
ATTRACTIONS = [
    {
        "name": "Alpha",
        "run_time": 10,
        "hourly_throughput": 3000,
        "popularity": 10,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Beta",
        "run_time": 5,
        "hourly_throughput": 2400,
        "popularity": 9,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Gamma",
        "run_time": 15,
        "hourly_throughput": 2000,
        "popularity": 8,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Delta",
        "run_time": 5,
        "hourly_throughput": 1200,
        "popularity": 7,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": False,
    },
    {
        "name": "Epsilon",
        "run_time": 10,
        "hourly_throughput": 2000,
        "popularity": 6,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": False,
        "adult_eligible": True,
    },
    {
        "name": "Zeta",
        "run_time": 6,
        "hourly_throughput": 2000,
        "popularity": 5,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": False,
    },
    {
        "name": "Eta",
        "run_time": 12,
        "hourly_throughput": 2400,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": False,
        "adult_eligible": True,
    }
]

# %% [markdown]
# ## Activities
# Activities are everything to do within the park that isn't an attraction.
#
# - Activities: list of dictionaries that describe activities within the park
#     - Name: name of the activity
#     - Popularity: Value from 1-10 that describes how popular an activity is with respect to other activities
#     - Mean Time: The expected time agents will spend at an activity

# %%
ACTIVITIES = [
    {
      "name": "sightseeing",
      "popularity": 5,
      "mean_time": 5
    },
    {
      "name": "show",
      "popularity": 5,
      "mean_time": 30
    },
    {
      "name": "merchandise",
      "popularity": 5,
      "mean_time": 30
    },
    {
      "name": "food",
      "popularity": 5,
      "mean_time": 45
    }
  ]

# %% [markdown]
# ## Plots
#
# Set the Y limit of plots

# %%
PLOT_RANGE = {
    "Attraction Queue Length": 'auto',
    "Attraction Wait Time": 'auto',
    "Attraction Expedited Queue Length": 'auto',
    "Attraction Expedited Wait Time": 'auto',
    "Activity Vistors": 'auto',
    "Approximate Agent Distribution (General)": 1.0,
    "Approximate Agent Distribution (Specific)": 1.0,
    "Attraction Average Wait Times": 'auto',
    "Agent Attractions Histogram": 1.0,
    "Attraction Total Visits": 'auto',
    "Expedited Pass Distribution": 'auto',
    "Age Class Distribution": 'auto',
}

# %% [markdown]
# ## Simulation
#
# Run the simulation here.

# %%
# Initialize Park
RNG_SEED = 5

park = Park(
    attraction_list=ATTRACTIONS,
    activity_list=ACTIVITIES,
    plot_range=PLOT_RANGE,
    random_seed=RNG_SEED,
    version=VERSION,
    verbosity=VERBOSITY
)

# Build Arrivals

park.generate_arrival_schedule(
    arrival_seed=HOURLY_PERCENT, 
    total_daily_agents=TOTAL_DAILY_AGENTS, 
    perfect_arrivals=PERFECT_ARRIVALS,
)

# Build Agents
park.generate_agents(
    behavior_archetype_distribution=AGENT_ARCHETYPE_DISTRIBUTION,
    exp_ability_pct=EXP_ABILITY_PCT,
    exp_wait_threshold=EXP_THRESHOLD,
    exp_limit=EXP_LIMIT
)

# Build Attractions + Activities
park.generate_attractions()
park.generate_activities()

# Pass Time
for _ in range(len(HOURLY_PERCENT.keys()) * 60):
    park.step()

# Save Parameters of Current Run
sim_parameters = {
    "VERSION": VERSION,
    "VERBOSITY": VERBOSITY,
    "SHOW_PLOTS": SHOW_PLOTS,
    "RNG_SEED": RNG_SEED,
    "TOTAL_DAILY_AGENTS": TOTAL_DAILY_AGENTS,
    "PERFECT_ARRIVALS": PERFECT_ARRIVALS,
    "HOURLY_PERCENT": HOURLY_PERCENT,
    "EXP_ABILITY_PCT": EXP_ABILITY_PCT,
    "EXP_THRESHOLD": EXP_THRESHOLD,
    "EXP_LIMIT": EXP_LIMIT,
    "AGENT_ARCHETYPE_DISTRIBUTION": AGENT_ARCHETYPE_DISTRIBUTION,
    "ATTRACTIONS": ATTRACTIONS,
    "ACTIVITIES": ACTIVITIES,
    "BEHAVIOR_ARCHETYPE_PARAMETERS": BEHAVIOR_ARCHETYPE_PARAMETERS,
}
park.write_data_to_file(
    data=sim_parameters, 
    output_file_path=f"{VERSION}/parameters", 
    output_file_format="json"
)

# Store + Print Data
park.make_plots(show=SHOW_PLOTS)
park.print_logs(N = 5)
#park.print_logs(selected_agent_ids = [778])
# Out:
# Time: 0
# Total Agents in Park: 162
# Attraction Wait Times (Minutes):
#      Eta: 0.0
#      Zeta: 0.0
#      Epsilon: 0.0
#      Delta: 0.0
#      Gamma: 0.0
#      Beta: 0.0
#      Alpha: 0.0
# Activity Visitor (Agents):
#      sightseeing: 0
#      show: 0
#      merchandise: 0
#      food: 0
# --------------------------------------------------
#
# Time: 60
# Total Agents in Park: 9235
# Attraction Wait Times (Minutes):
#      Eta: 12.0
#      Zeta: 12.0
#      Epsilon: 20.0
#      Delta: 20.0
#      Gamma: 30.0
#      Beta: 15.0
#      Alpha: 30.0
# Activity Visitor (Agents):
#      sightseeing: 253
#      show: 1385
#      merchandise: 1411
#      food: 1698
# --------------------------------------------------
#
# Time: 120
# Total Agents in Park: 20572
# Attraction Wait Times (Minutes):
#      Eta: 24.0
#      Zeta: 24.0
#      Epsilon: 20.0
#      Delta: 25.0
#      Gamma: 75.0
#      Beta: 50.0
#      Alpha: 50.0
# Activity Visitor (Agents):
#      sightseeing: 505
#      show: 3070
#      merchandise: 3141
#      food: 4168
# --------------------------------------------------
#
# Time: 180
# Total Agents in Park: 28643
# Attraction Wait Times (Minutes):
#      Eta: 36.0
#      Zeta: 36.0
#      Epsilon: 40.0
#      Delta: 75.0
#      Gamma: 75.0
#      Beta: 90.0
#      Alpha: 50.0
# Activity Visitor (Agents):
#      sightseeing: 713
#      show: 4201
#      merchandise: 4231
#      food: 6021
# --------------------------------------------------
#
# Time: 240
# Total Agents in Park: 34975
# Attraction Wait Times (Minutes):
#      Eta: 60.0
#      Zeta: 60.0
#      Epsilon: 70.0
#      Delta: 95.0
#      Gamma: 90.0
#      Beta: 70.0
#      Alpha: 60.0
# Activity Visitor (Agents):
#      sightseeing: 932
#      show: 5333
#      merchandise: 5253
#      food: 7532
# --------------------------------------------------
#
# Time: 300
# Total Agents in Park: 37443
# Attraction Wait Times (Minutes):
#      Eta: 72.0
#      Zeta: 102.0
#      Epsilon: 100.0
#      Delta: 120.0
#      Gamma: 105.0
#      Beta: 115.0
#      Alpha: 100.0
# Activity Visitor (Agents):
#      sightseeing: 928
#      show: 5733
#      merchandise: 5613
#      food: 8241
# --------------------------------------------------
#
# Time: 360
# Total Agents in Park: 37400
# Attraction Wait Times (Minutes):
#      Eta: 84.0
#      Zeta: 96.0
#      Epsilon: 110.0
#      Delta: 145.0
#      Gamma: 120.0
#      Beta: 135.0
#      Alpha: 110.0
# Activity Visitor (Agents):
#      sightseeing: 911
#      show: 5638
#      merchandise: 5640
#      food: 8293
# --------------------------------------------------
#
# Time: 420
# Total Agents in Park: 33545
# Attraction Wait Times (Minutes):
#      Eta: 84.0
#      Zeta: 96.0
#      Epsilon: 110.0
#      Delta: 145.0
#      Gamma: 120.0
#      Beta: 135.0
#      Alpha: 110.0
# Activity Visitor (Agents):
#      sightseeing: 769
#      show: 5060
#      merchandise: 4998
#      food: 7415
# --------------------------------------------------
#
# Time: 480
# Total Agents in Park: 30141
# Attraction Wait Times (Minutes):
#      Eta: 72.0
#      Zeta: 72.0
#      Epsilon: 90.0
#      Delta: 135.0
#      Gamma: 120.0
#      Beta: 125.0
#      Alpha: 100.0
# Activity Visitor (Agents):
#      sightseeing: 702
#      show: 4482
#      merchandise: 4462
#      food: 6562
# --------------------------------------------------
#
# Time: 540
# Total Agents in Park: 25494
# Attraction Wait Times (Minutes):
#      Eta: 60.0
#      Zeta: 60.0
#      Epsilon: 80.0
#      Delta: 105.0
#      Gamma: 105.0
#      Beta: 95.0
#      Alpha: 90.0
# Activity Visitor (Agents):
#      sightseeing: 606
#      show: 3636
#      merchandise: 3862
#      food: 5441
# --------------------------------------------------
#
# Time: 600
# Total Agents in Park: 20219
# Attraction Wait Times (Minutes):
#      Eta: 36.0
#      Zeta: 66.0
#      Epsilon: 90.0
#      Delta: 160.0
#      Gamma: 135.0
#      Beta: 110.0
#      Alpha: 100.0
# Activity Visitor (Agents):
#      sightseeing: 422
#      show: 2635
#      merchandise: 2564
#      food: 4002
# --------------------------------------------------
#
# Time: 660
# Total Agents in Park: 15137
# Attraction Wait Times (Minutes):
#      Eta: 24.0
#      Zeta: 12.0
#      Epsilon: 30.0
#      Delta: 145.0
#      Gamma: 120.0
#      Beta: 80.0
#      Alpha: 80.0
# Activity Visitor (Agents):
#      sightseeing: 304
#      show: 2086
#      merchandise: 2013
#      food: 3019
# --------------------------------------------------
#
# Time: 720
# Total Agents in Park: 10657
# Attraction Wait Times (Minutes):
#      Eta: 12.0
#      Zeta: 6.0
#      Epsilon: 20.0
#      Delta: 105.0
#      Gamma: 45.0
#      Beta: 25.0
#      Alpha: 20.0
# Activity Visitor (Agents):
#      sightseeing: 214
#      show: 1606
#      merchandise: 1586
#      food: 2365
# --------------------------------------------------
# +--------------+---------------------+--------------+
# | Attraction   |   Average Wait Time | Queue Type   |
# |--------------+---------------------+--------------|
# | Eta          |                5.49 | Expedited    |
# | Zeta         |                2.50 | Expedited    |
# | Epsilon      |                4.49 | Expedited    |
# | Delta        |                2.43 | Expedited    |
# | Gamma        |                7.29 | Expedited    |
# | Beta         |                2.30 | Expedited    |
# | Alpha        |                4.59 | Expedited    |
# | Eta          |               38.68 | Standby      |
# | Zeta         |               58.22 | Standby      |
# | Epsilon      |               63.79 | Standby      |
# | Delta        |               93.00 | Standby      |
# | Gamma        |               80.94 | Standby      |
# | Beta         |               84.23 | Standby      |
# | Alpha        |               69.05 | Standby      |
# +--------------+---------------------+--------------+
# +----------+-----------------------------+
# | Metric   |   Total Attractions Visited |
# |----------+-----------------------------|
# | count    |                    50000.00 |
# | mean     |                        3.35 |
# | std      |                        2.42 |
# | min      |                        0.00 |
# | 25%      |                        2.00 |
# | 50%      |                        3.00 |
# | 75%      |                        5.00 |
# | max      |                       18.00 |
# +----------+-----------------------------+
# +--------------+----------+
# | Attraction   |   Visits |
# |--------------+----------|
# | Alpha        |    34585 |
# | Beta         |    28782 |
# | Delta        |    14897 |
# | Epsilon      |    21545 |
# | Eta          |    22587 |
# | Gamma        |    23555 |
# | Zeta         |    21386 |
# +--------------+----------+
# +--------------------+----------------+-------------+
# | Expedited Passes   |   Total Passes | Type        |
# |--------------------+----------------+-------------|
# |                    |          78924 | Distributed |
# |                    |          56270 | Redeemed    |
# +--------------------+----------------+-------------+
# +-------------+----------+----------------+
# | Age Class   |   Agents | Type           |
# |-------------+----------+----------------|
# |             |    14981 | No Adult Rides |
# |             |     8247 | No Child Rides |
# |             |    26772 | No Preference  |
# +-------------+----------+----------------+
# Agent ID: 40822
# Agent Archetype: park_visitor
# Agent arrived at park at time 296. Agent picked up an expedited pass for Zeta at time 301. The expedited queue return time is in 39 minutes. Agent visited the activity sightseeing at time 307. Agent exited the activity sightseeing at time 311. Agent visited the activity merchandise at time 317. Agent exited the activity merchandise at time 340. Agent entered exp queue for Zeta at time 346. Agent boarded Zeta and redeemed their expedited queue pass at time 348. Agent exited Zeta at time 354. Agent visited the activity sightseeing at time 360. Agent exited the activity sightseeing at time 364. Agent visited the activity merchandise at time 370. Agent exited the activity merchandise at time 397. Agent visited the activity show at time 403. Agent exited the activity show at time 430. Agent visited the activity food at time 436. Agent exited the activity food at time 477. Agent picked up an expedited pass for Alpha at time 483. The expedited queue return time is in 152 minutes. Agent entered queue for Delta at time 489. Agent boarded Delta at time 525. Agent exited Delta at time 530. Agent visited the activity sightseeing at time 536. Agent exited the activity sightseeing at time 540. Agent visited the activity show at time 546. Agent exited the activity show at time 573. Agent visited the activity show at time 579. Agent exited the activity show at time 606. Agent visited the activity merchandise at time 612. Agent exited the activity merchandise at time 635. Agent left park at 641.
#
# Agent ID: 16740
# Agent Archetype: ride_favorer
# Agent arrived at park at time 99. Agent picked up an expedited pass for Alpha at time 104. The expedited queue return time is in 11 minutes. Agent visited the activity merchandise at time 110. Agent exited the activity merchandise at time 115. Agent entered exp queue for Alpha at time 121. Agent boarded Alpha and redeemed their expedited queue pass at time 130. Agent exited Alpha at time 140. Agent picked up an expedited pass for Delta at time 146. The expedited queue return time is in 44 minutes. Agent entered queue for Zeta at time 152. Agent boarded Zeta at time 156. Agent exited Zeta at time 162. Agent visited the activity food at time 168. Agent exited the activity food at time 190. Agent entered exp queue for Delta at time 196. Agent boarded Delta and redeemed their expedited queue pass at time 200. Agent exited Delta at time 205. Agent visited the activity show at time 211. Agent exited the activity show at time 244. Agent visited the activity food at time 250. Agent exited the activity food at time 299. Agent picked up an expedited pass for Beta at time 305. The expedited queue return time is in 145 minutes. Agent visited the activity food at time 311. Agent exited the activity food at time 360. Agent visited the activity food at time 366. Agent exited the activity food at time 415. Agent visited the activity food at time 421. Agent exited the activity food at time 450. Agent entered exp queue for Beta at time 456. Agent boarded Beta and redeemed their expedited queue pass at time 460. Agent exited Beta at time 465. Agent picked up an expedited pass for Zeta at time 471. The expedited queue return time is in 44 minutes. Agent visited the activity merchandise at time 477. Agent exited the activity merchandise at time 510. Agent visited the activity sightseeing at time 516. Agent exited the activity sightseeing at time 517. Agent entered exp queue for Zeta at time 523. Agent boarded Zeta and redeemed their expedited queue pass at time 528. Agent exited Zeta at time 534. Agent picked up an expedited pass for Beta at time 540. The expedited queue return time is in 220 minutes. Agent entered queue for Alpha at time 546. Agent boarded Alpha at time 570. Agent exited Alpha at time 580. Agent visited the activity merchandise at time 586. Agent exited the activity merchandise at time 619. Agent entered queue for Gamma at time 625. Agent boarded Gamma at time 660. Agent exited Gamma at time 675. Agent left park at 681.
#
# Agent ID: 48613
# Agent Archetype: park_tourer
# Agent arrived at park at time 504. Agent picked up an expedited pass for Beta at time 509. The expedited queue return time is in 211 minutes. Agent entered queue for Alpha at time 515. Agent boarded Alpha at time 540. Agent exited Alpha at time 550. Agent visited the activity merchandise at time 556. Agent exited the activity merchandise at time 573. Agent visited the activity food at time 579. Agent exited the activity food at time 605. Agent visited the activity food at time 611. Agent exited the activity food at time 637. Agent visited the activity food at time 643. Agent exited the activity food at time 669. Agent visited the activity sightseeing at time 675. Agent exited the activity sightseeing at time 677. Agent visited the activity show at time 683. Agent exited the activity show at time 700. Agent entered queue for Eta at time 706. Agent boarded Eta at time 708. Agent exited Eta at time 720. Agent entered exp queue for Beta at time 726. Agent boarded Beta and redeemed their expedited queue pass at time 730. Agent exited Beta at time 735. Agent visited the activity merchandise at time 741. Agent exited the activity merchandise at time 758. Agent visited the activity show at time 764.
#
# Agent ID: 23496
# Agent Archetype: park_visitor
# Agent arrived at park at time 140. Agent picked up an expedited pass for Alpha at time 145. The expedited queue return time is in 20 minutes. Agent visited the activity sightseeing at time 151. Agent exited the activity sightseeing at time 158. Agent visited the activity food at time 164. Agent exited the activity food at time 165. Agent entered exp queue for Alpha at time 171. Agent boarded Alpha and redeemed their expedited queue pass at time 180. Agent exited Alpha at time 190. Agent visited the activity show at time 196. Agent exited the activity show at time 243. Agent picked up an expedited pass for Gamma at time 249. The expedited queue return time is in 141 minutes. Agent visited the activity show at time 255. Agent exited the activity show at time 302. Agent visited the activity sightseeing at time 308. Agent exited the activity sightseeing at time 315. Agent visited the activity show at time 321. Agent exited the activity show at time 368. Agent visited the activity merchandise at time 374. Agent exited the activity merchandise at time 390. Agent entered exp queue for Gamma at time 396. Agent boarded Gamma and redeemed their expedited queue pass at time 405. Agent exited Gamma at time 420. Agent visited the activity show at time 426. Agent exited the activity show at time 473. Agent visited the activity food at time 479. Agent exited the activity food at time 550. Agent left park at 556.
#
# Agent ID: 45249
# Agent Archetype: park_tourer
# Agent arrived at park at time 404. Agent visited the activity merchandise at time 409. Agent exited the activity merchandise at time 443. Agent visited the activity merchandise at time 449. Agent exited the activity merchandise at time 483. Agent picked up an expedited pass for Gamma at time 489. The expedited queue return time is in 276 minutes. Agent visited the activity merchandise at time 495. Agent exited the activity merchandise at time 529. Agent entered queue for Beta at time 535. Agent boarded Beta at time 565. Agent exited Beta at time 570. Agent entered queue for Eta at time 576. Agent boarded Eta at time 588. Agent exited Eta at time 600. Agent entered queue for Alpha at time 606. Agent boarded Alpha at time 630. Agent exited Alpha at time 640. Agent visited the activity food at time 646. Agent exited the activity food at time 698. Agent visited the activity merchandise at time 704. Agent exited the activity merchandise at time 738. Agent entered queue for Zeta at time 744. Agent boarded Zeta at time 744. Agent exited Zeta at time 750. Agent visited the activity show at time 756. Agent exited the activity show at time 765. Agent entered exp queue for Gamma at time 771.

# %%
park.agents[2].log
#park.plot_range = PLOT_RANGE
#park.make_plots(show=SHOW_PLOTS)
# Out:
# 'Agent arrived at park at time 0. Agent visited the activity show at time 5. Agent exited the activity show at time 35. Agent entered queue for Gamma at time 41. Agent boarded Gamma at time 45. Agent exited Gamma at time 60. Agent visited the activity food at time 66. Agent exited the activity food at time 111. Agent visited the activity sightseeing at time 117. Agent exited the activity sightseeing at time 122. Agent visited the activity sightseeing at time 128. Agent exited the activity sightseeing at time 133. Agent visited the activity sightseeing at time 139. Agent exited the activity sightseeing at time 144. Agent visited the activity merchandise at time 150. Agent exited the activity merchandise at time 180. Agent entered queue for Eta at time 186. Agent boarded Eta at time 192. Agent exited Eta at time 204. Agent picked up an expedited pass for Beta at time 210. The expedited queue return time is in 80 minutes. Agent entered queue for Eta at time 216. Agent boarded Eta at time 228. Agent exited Eta at time 240. Agent entered queue for Eta at time 246. Agent boarded Eta at time 252. Agent exited Eta at time 264. Agent visited the activity sightseeing at time 270. Agent exited the activity sightseeing at time 275. Agent visited the activity food at time 281. Agent exited the activity food at time 290. Agent entered exp queue for Beta at time 296. Agent boarded Beta and redeemed their expedited queue pass at time 300. Agent exited Beta at time 305. Agent visited the activity show at time 311. Agent exited the activity show at time 341. Agent picked up an expedited pass for Gamma at time 347. The expedited queue return time is in 213 minutes. Agent entered queue for Alpha at time 353. Agent boarded Alpha at time 410. Agent exited Alpha at time 420. Agent visited the activity food at time 426. Agent exited the activity food at time 471. Agent visited the activity food at time 477. Agent exited the activity food at time 522. Agent left park at 528. '

# %%
#import numpy as np
#rng = np.random.default_rng(10+23496)
#mean_time = 45
#rng.normal(mean_time, mean_time/2, 15)
#max((rng.normal(mean_time, mean_time/2, 1))[0], 1)
#park.activities['food'].state["visitor_time_remaining"]

#[
#            (ind, agent_id) for ind, agent_id in enumerate(park.activities['food'].state["visitors"])
#            if park.activities['food'].state["visitor_time_remaining"][ind] == 0
#        ]

park.agents[11748].log
# Out:
# 'Agent arrived at park at time 74. Agent visited the activity show at time 79. Agent exited the activity show at time 103. Agent visited the activity merchandise at time 109. Agent exited the activity merchandise at time 133. Agent entered queue for Alpha at time 139. Agent boarded Alpha at time 150. Agent exited Alpha at time 160. Agent picked up an expedited pass for Delta at time 166. The expedited queue return time is in 79 minutes. Agent entered queue for Zeta at time 172. Agent boarded Zeta at time 174. Agent exited Zeta at time 180. Agent visited the activity show at time 186. Agent exited the activity show at time 210. Agent visited the activity merchandise at time 216. Agent exited the activity merchandise at time 240. Agent visited the activity show at time 246. Agent exited the activity show at time 247. Agent entered exp queue for Delta at time 253. Agent boarded Delta and redeemed their expedited queue pass at time 260. Agent exited Delta at time 265. Agent picked up an expedited pass for Beta at time 271. The expedited queue return time is in 124 minutes. Agent entered queue for Gamma at time 277. Agent boarded Gamma at time 330. Agent exited Gamma at time 345. Agent visited the activity merchandise at time 351. Agent exited the activity merchandise at time 375. Agent left park at 381. '

# %%
park.attractions['Alpha'].capacity#history["exp_queue_length"]#state["agents_in_attraction"])
# agents_in_attraction, queue, exp_queue, exp_queue_passes_distributed, exp_queue_passes_skipped,
# exp_return_time

# attraction.capacity --> capacity of each cycle, not guests per minute! no wonder.
# Out:
# 500.0

# %%
a = 17/3
(a + (5 - a % 5))
# Out:
# 10.0
